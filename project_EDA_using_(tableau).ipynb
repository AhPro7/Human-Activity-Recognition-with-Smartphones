# %% [markdown]
# <a href="https://colab.research.google.com/github/AhPro7/Human-Activity-Recognition-with-Smartphones/blob/main/project_EDA_using_(tableau).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.express as px

# %% [markdown]
# ## Quick overview

# %%
train_data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Machinfy/train.csv')
test_data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Machinfy/test.csv')

# %%
train_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject  Activity
# 0           0.288585          -0.020294  ...        1  STANDING
# 1           0.278419          -0.016411  ...        1  STANDING
# 2           0.279653          -0.019467  ...        1  STANDING
# 3           0.279174          -0.026201  ...        1  STANDING
# 4           0.276629          -0.016570  ...        1  STANDING
#
# [5 rows x 563 columns]

# %%
test_data.head()
# Out:
#    tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  subject  Activity
# 0           0.257178          -0.023285  ...        2  STANDING
# 1           0.286027          -0.013163  ...        2  STANDING
# 2           0.275485          -0.026050  ...        2  STANDING
# 3           0.270298          -0.032614  ...        2  STANDING
# 4           0.274833          -0.027848  ...        2  STANDING
#
# [5 rows x 563 columns]

# %%
print('train ==> ',train_data.shape)
print('test  ==> ',test_data.shape)
# Out:
# train ==>  (7352, 563)
# test  ==>  (2947, 563)

# %%
train_data.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  ...  angle(Z,gravityMean)      subject
# count        7352.000000        7352.000000  ...           7352.000000  7352.000000
# mean            0.274488          -0.017695  ...             -0.056515    17.413085
# std             0.070261           0.040811  ...              0.279122     8.975143
# min            -1.000000          -1.000000  ...             -1.000000     1.000000
# 25%             0.262975          -0.024863  ...             -0.143414     8.000000
# 50%             0.277193          -0.017219  ...              0.003181    19.000000
# 75%             0.288461          -0.010783  ...              0.107659    26.000000
# max             1.000000           1.000000  ...              1.000000    30.000000
#
# [8 rows x 562 columns]

# %%
# duplicates ?

print ('Num of duplicates in train_data ==> ',sum(train_data.duplicated()))
print ('Num of duplicates in test_data  ==> ',sum(test_data.duplicated()))
# Out:
# Num of duplicates in train_data ==>  0
# Num of duplicates in test_data  ==>  0

# %%
# null ?

print('Num of Null values in train_data ==> ',train_data.isnull().values.sum())
print('Num of Null values in test_data  ==> ',test_data.isnull().values.sum())
# Out:
# Num of Null values in train_data ==>  0
# Num of Null values in test_data  ==>  0

# %% [markdown]
# 1. we have 0 duplicates values
# 2. we have 0 null values
# 3. we have out layers

# %%
train_data.dtypes
# Out:
# tBodyAcc-mean()-X       float64
# tBodyAcc-mean()-Y       float64
# tBodyAcc-mean()-Z       float64
# tBodyAcc-std()-X        float64
# tBodyAcc-std()-Y        float64
#                          ...
# angle(X,gravityMean)    float64
# angle(Y,gravityMean)    float64
# angle(Z,gravityMean)    float64
# subject                   int64
# Activity                 object
# Length: 563, dtype: object

# %%
cat_col = train_data.select_dtypes(include=['object'])
cat_col
# Out:
#               Activity
# 0             STANDING
# 1             STANDING
# 2             STANDING
# 3             STANDING
# 4             STANDING
# ...                ...
# 7347  WALKING_UPSTAIRS
# 7348  WALKING_UPSTAIRS
# 7349  WALKING_UPSTAIRS
# 7350  WALKING_UPSTAIRS
# 7351  WALKING_UPSTAIRS
#
# [7352 rows x 1 columns]

# %%
numf_col = train_data.select_dtypes(include=['float64'])
numi_col = train_data.select_dtypes(include=['int64'])

len(numf_col.columns)+len(numi_col.columns)
# Out:
# 562

# %% [markdown]
# we have 562 numeric and one

# %% [markdown]
#  imbalance  ?

# %%
data = pd.concat([train_data , test_data])

# %%
data['Activity'].groupby(data['Activity']).count()
# Out:
# Activity
# LAYING                1944
# SITTING               1777
# STANDING              1906
# WALKING               1722
# WALKING_DOWNSTAIRS    1406
# WALKING_UPSTAIRS      1544
# Name: Activity, dtype: int64

# %%
data['subject'].unique()
# Out:
# array([ 1,  3,  5,  6,  7,  8, 11, 14, 15, 16, 17, 19, 21, 22, 23, 25, 26,
#        27, 28, 29, 30,  2,  4,  9, 10, 12, 13, 18, 20, 24])

# %%
px.histogram(data_frame=data, x="subject", color="Activity",barmode='group',width=1200)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b9a4add3-61b2-4312-a3e9-fce29f73b2c0" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b9a4add3-61b2-4312-a3e9-fce29f73b2c0")) {
#                     Plotly.newPlot(
#                         'b9a4add3-61b2-4312-a3e9-fce29f73b2c0',
# ...

# %% [markdown]
# As we can see We have got almost same number of reading from all the subjects means there are not sygnificant difference in reading then we should not worry about it

# %%
df = data
fig = px.pie(df, names='Activity',width=1200)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1dd6f50d-cbbf-46d1-9899-2359b0210fbe" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1dd6f50d-cbbf-46d1-9899-2359b0210fbe")) {
#                     Plotly.newPlot(
#                         '1dd6f50d-cbbf-46d1-9899-2359b0210fbe',
# ...

# %%
fig = px.histogram (df,x="Activity", y="subject",width=1200,color='Activity')
fig.update_layout(barmode='group')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="015c6cf3-f3c0-4fd5-992a-6cd64283a28b" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("015c6cf3-f3c0-4fd5-992a-6cd64283a28b")) {
#                     Plotly.newPlot(
#                         '015c6cf3-f3c0-4fd5-992a-6cd64283a28b',
# ...

# %%
fig = px.box(df, y='subject', x="Activity",color="Activity",width=1200,boxmode="overlay",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fb9ec22b-a1f6-4589-83f3-818340914435" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fb9ec22b-a1f6-4589-83f3-818340914435")) {
#                     Plotly.newPlot(
#                         'fb9ec22b-a1f6-4589-83f3-818340914435',
# ...

# %% [markdown]
# Data is blanced

# %% [markdown]
# 1. In static activities ACC information will not be very useful.
# 2. In the dynamic activities  ACC info will be significant.
#
# Let's consider **tBodyAccMag-mean()** feature to differentiate among these two broader set of activities.
# using **Pdf**

# %%
px.histogram(data_frame=df,
             x='tBodyAccMag-mean()',
             y="Activity",
             color='Activity', 
             histnorm='probability density',
             )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="28b36773-7a67-4761-9d8b-8e3b2cc8c58c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("28b36773-7a67-4761-9d8b-8e3b2cc8c58c")) {
#                     Plotly.newPlot(
#                         '28b36773-7a67-4761-9d8b-8e3b2cc8c58c',
# ...

# %% [markdown]
# ```
# if(tBodyAccMag-mean()<=-0.5):
#     Activity = "static"
# else:
#     Activity = "dynamic"
# ```

# %%
fig = px.box(df, y='tBodyAccMag-mean()', x="Activity",color="Activity",width=1200,boxmode="overlay",)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="3424a98e-e1ba-4ffc-86c2-089cb3df192b" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3424a98e-e1ba-4ffc-86c2-089cb3df192b")) {
#                     Plotly.newPlot(
#                         '3424a98e-e1ba-4ffc-86c2-089cb3df192b',
# ...

# %% [markdown]
# Using boxplot again we can come with conditions to seperate static activities from dynamic activities.
#
# ```
# if(tBodyAccMag-mean()<=-0.8):
#     Activity = "static"
# if(tBodyAccMag-mean()>=-0.6):
#     Activity = "dynamic"
# ```
#
# Also, we can easily seperate WALKING_DOWNSTAIRS activity from others using boxplot.
#
# ```
# if(tBodyAccMag-mean()>0.02):
#     Activity = "WALKING_DOWNSTAIRS"
# else:
#     Activity = "others"
# ```
#
# But still 25% of WALKING_DOWNSTAIRS observations are below 0.02 which are misclassified as **others** so this condition makes an error of 25% in classification.

# %%
fig = px.box(df, y='angle(X,gravityMean)', x="Activity",color="Activity",width=1200,boxmode="overlay")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d2db7019-7f58-45df-a432-b03884721865" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d2db7019-7f58-45df-a432-b03884721865")) {
#                     Plotly.newPlot(
#                         'd2db7019-7f58-45df-a432-b03884721865',
# ...

# %%
fig = px.bar(df, x='angle(X,gravityMean)', y="Activity",color="Activity",width=1200,orientation='h',barmode='overlay')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="383fe46a-5e2c-496f-8c9b-3302793683dc" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("383fe46a-5e2c-496f-8c9b-3302793683dc")) {
#                     Plotly.newPlot(
#                         '383fe46a-5e2c-496f-8c9b-3302793683dc',
# ...

# %% [markdown]
# From the boxplot and bar we can observe that angle(X,gravityMean) perfectly seperates LAYING from other activities.
# ```
# if(angle(X,gravityMean)>0.01):
#     Activity = "LAYING"
# else:
#     Activity = "others"
# ```

# %%
fig = px.box(df, y='angle(Y,gravityMean)', x="Activity",color="Activity",width=1200,boxmode="overlay")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="346a485a-708f-4019-9af3-b7b7c76852bf" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("346a485a-708f-4019-9af3-b7b7c76852bf")) {
#                     Plotly.newPlot(
#                         '346a485a-708f-4019-9af3-b7b7c76852bf',
# ...

# %%
fig = px.box(df, y='tGravityAcc-energy()-Y', x="Activity",color="Activity",width=1200,boxmode="overlay")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="23b18ee3-4d9e-4e14-8c11-386bdfece749" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("23b18ee3-4d9e-4e14-8c11-386bdfece749")) {
#                     Plotly.newPlot(
#                         '23b18ee3-4d9e-4e14-8c11-386bdfece749',
# ...

# %%
fig = px.bar(df, x='tGravityAcc-energy()-Y', y="Activity",color="Activity",width=1200,orientation='h',barmode='overlay')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="abf53cfe-4a85-4c2b-804d-0b39ebb1b05e" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("abf53cfe-4a85-4c2b-804d-0b39ebb1b05e")) {
#                     Plotly.newPlot(
#                         'abf53cfe-4a85-4c2b-804d-0b39ebb1b05e',
# ...

# %% [markdown]
# From the boxplot and bar we can observe that (tGravityAcc-energy()-Y) perfectly seperates LAYING from other activities.
# ```
# if(tGravityAcc-energy()-Y)>0):
#     Activity = "LAYING"
# else:
#     Activity = "others"
# ```

# %%
fig = px.box(df, y='fBodyAcc-bandsEnergy()-1,8', x="Activity",color="Activity",width=1200,boxmode="overlay")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="db66b4dd-866c-4c74-a4ec-3884876224f6" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("db66b4dd-866c-4c74-a4ec-3884876224f6")) {
#                     Plotly.newPlot(
#                         'db66b4dd-866c-4c74-a4ec-3884876224f6',
# ...

# %%
fig = px.bar(df, x='fBodyAcc-bandsEnergy()-1,8', y="Activity",color="Activity",width=1200,orientation='h',barmode='overlay')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c1a402cc-68d6-4d3a-aff2-53092405f653" class="plotly-graph-div" style="height:525px; width:1200px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c1a402cc-68d6-4d3a-aff2-53092405f653")) {
#                     Plotly.newPlot(
#                         'c1a402cc-68d6-4d3a-aff2-53092405f653',
# ...

# %% [markdown]
# From the boxplot and bar we can observe that (fBodyAcc-bandsEnergy()-1,8) perfectly seperates LAYING from other activities.
# ```
# if(fBodyAcc-bandsEnergy()-1,8)>0):
#     Activity = "Walking_downstairs"
# else:
#     Activity = "others"
# ```
